# %%
import logging

logger = logging.getLogger()
logger.setLevel(logging.INFO)

# %%
import requests
import time
from tqdm import tqdm
from bs4 import BeautifulSoup
from fastcore.all import Path

data_path = Path("./data/games")
steam_links_path = data_path / "links.txt"

# We can use this to get the links to all Steam games based on the regular Steam search functionality. It is a good starting point
# for scraping the game pages for more information and images
def get_all_steam_games() -> list[str]:
    steam_url = "https://store.steampowered.com/search/results/?query&start={start}&count=50&dynamic_data=&sort_by=_ASC&supportedlang=english&snr=1_7_7_230_7&infinite=1"
    first_page = requests.get(steam_url.format(start=0)).json()
    total_count = first_page["total_count"]

    steam_links: list[str] = []    
    processed_links: set[str] = set()

    # We save the list of processed links to make scraping resumable. If we have a checkpoint read it, and continue from there
    if steam_links_path.exists():
        steam_links = steam_links_path.read_text().splitlines()
        processed_links = set(steam_links)

    for start in tqdm(range(len(processed_links), total_count, 50)):
        response = requests.get(steam_url.format(start=start))

        # Let's fail quickly here and see why we got an error. That way we can adjust the flow if needed
        response.raise_for_status()

        # Grab all game/content links in the returned response
        response = response.json()
        page_content = BeautifulSoup(response["results_html"], "html.parser")
        links = page_content.find_all("a", { "data-ds-appid": True })
        new_links = [link["href"] for link in links if link["href"] not in processed_links]

        # And checkpoint. This just overwrites the file everyime time. It's not the most efficient, but it's simple and easy to understand
        steam_links.extend(new_links)
        processed_links = set(steam_links)
        steam_links_path.write_text("\n".join(steam_links))

        # Slightly throttle the requests so we don't get rate limited, but Steam seems to be pretty forgiving
        time.sleep(0.1)

    return steam_links

# When we have a good enough checkpoint, we can just read the list from the file
def read_steam_links_from_file() -> list[str]:
    ids = steam_links_path.read_text().splitlines()
    # This deduplicates the list (from Python 3.7 dictionaries are ordered, which is why we're not using sets here)
    # Steam results are returned in order of popularity and we'd like to keep it that way
    return list(dict.fromkeys(ids))

# steam_links = get_all_steam_games()
steam_links = read_steam_links_from_file()
steam_links[:10]
# Out:
# ['https://store.steampowered.com/app/553850/HELLDIVERS_2/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/1086940/Baldurs_Gate_3/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/1172470/Apex_Legends/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/1158310/Crusader_Kings_III/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/899770/Last_Epoch/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/2379780/Balatro/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/2670630/Supermarket_Simulator/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/1085660/Destiny_2/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/230410/Warframe/?snr=1_7_7_230_150_1',
#  'https://store.steampowered.com/app/1938090/Call_of_Duty/?snr=1_7_7_230_150_1']

# %%
import msgspec
from datetime import date, datetime
from typing import Optional, Literal
from urllib.parse import urlparse

SteamUrlType = Literal["app", "sub"]

class SteamReview(msgspec.Struct):
    sentiment: str
    number_of_reviewers: int
    positive_percentage: int

class SteamPageInformation(msgspec.Struct):
    type: Literal["game", "dlc", "package"]

    title: str
    description: Optional[str]
    price: Optional[int]
    images: list[str]
    genres: list[str]
    tags: list[str]
    developers: list[str]
    publishers: list[str]
    release_date: Optional[str]
    recent_reviews: Optional[SteamReview]
    all_reviews: Optional[SteamReview]

class SteamGame(msgspec.Struct):
    id: str
    url: str
    raw_name: Optional[str]
    url_type: SteamUrlType
    popularity_rank: int
    page_information: Optional[SteamPageInformation]

    def crawled_page_id(self) -> str:
        return f"{self.id}_{self.raw_name or 'Unknown'}"
        
def create_steam_game_list(urls: list[str]) -> list[SteamGame]:
    games: dict[str, SteamGame] = {}

    popularity_rank = 1
    for url_with_query in urls:
        url = urlparse(url_with_query)._replace(query=None)
        path_segments = url.path.strip('/').split('/')
        
        if len(path_segments) < 2:
            raise ValueError(f"Invalid url: {url_with_query}")

        url_type = path_segments[0]
        id = path_segments[1]
        name = path_segments[2] if len(path_segments) > 2 else None

        if url.path not in games:
            url_type = msgspec.json.decode(f'"{url_type}"', type=SteamUrlType)
            games[url.path] = SteamGame(id=id, url=url.geturl(), raw_name=name, url_type=url_type, popularity_rank=popularity_rank, page_information=None)
            popularity_rank += 1
        

    return list(games.values())


steam_games = create_steam_game_list(steam_links)
steam_games[:10]
# Out:
# [SteamGame(id='553850', url='https://store.steampowered.com/app/553850/HELLDIVERS_2/', raw_name='HELLDIVERS_2', url_type='app', popularity_rank=1, page_information=None),
#  SteamGame(id='1086940', url='https://store.steampowered.com/app/1086940/Baldurs_Gate_3/', raw_name='Baldurs_Gate_3', url_type='app', popularity_rank=2, page_information=None),
#  SteamGame(id='1172470', url='https://store.steampowered.com/app/1172470/Apex_Legends/', raw_name='Apex_Legends', url_type='app', popularity_rank=3, page_information=None),
#  SteamGame(id='1158310', url='https://store.steampowered.com/app/1158310/Crusader_Kings_III/', raw_name='Crusader_Kings_III', url_type='app', popularity_rank=4, page_information=None),
#  SteamGame(id='899770', url='https://store.steampowered.com/app/899770/Last_Epoch/', raw_name='Last_Epoch', url_type='app', popularity_rank=5, page_information=None),
#  SteamGame(id='2379780', url='https://store.steampowered.com/app/2379780/Balatro/', raw_name='Balatro', url_type='app', popularity_rank=6, page_information=None),
#  SteamGame(id='2670630', url='https://store.steampowered.com/app/2670630/Supermarket_Simulator/', raw_name='Supermarket_Simulator', url_type='app', popularity_rank=7, page_information=None),
#  SteamGame(id='1085660', url='https://store.steampowered.com/app/1085660/Destiny_2/', raw_name='Destiny_2', url_type='app', popularity_rank=8, page_information=None),
#  SteamGame(id='230410', url='https://store.steampowered.com/app/230410/Warframe/', raw_name='Warframe', url_type='app', popularity_rank=9, page_information=None),
#  SteamGame(id='1938090', url='https://store.steampowered.com/app/1938090/Call_of_Duty/', raw_name='Call_of_Duty', url_type='app', popularity_rank=10, page_information=None)]

# %%
from requests.adapters import HTTPAdapter, Retry
from tqdm.contrib.concurrent import thread_map

steam_game_pages_path = data_path / "pages"

# Crawls a single steam content page with the given session. It returns the game's ID and whether it was successfully crawled
def crawl_game_information_page(game: SteamGame, session: requests.Session) -> tuple[str, bool]:
    # We save crawled HTML pages so that we can resume from where we left off. If this game has a corresponding file,
    # just return that one
    page_content_path = steam_game_pages_path / f"{game.crawled_page_id()}.html"
    if page_content_path.exists():
        return game.url, True

    response = session.get(game.url)
    if response.ok:
        page_content_path.write_text(response.text)
        return game.url, True
    else:
        return game.url, False

def crawl_all_pages(games: list[SteamGame]):
    # Set up a session with automatic retries and connection pooling
    session = requests.Session()
    session.mount("https://", HTTPAdapter(max_retries=Retry(total=3, backoff_factor=0.1, status_forcelist=[500, 502, 503, 504])))

    # Don't use too many workers so Steam doesn't rate limit us
    results = thread_map(lambda game: crawl_game_information_page(game, session), games, max_workers=8)

    return results

page_crawl_results = crawl_all_pages(steam_games)
page_crawl_results[:10], len(list(filter(lambda result: not result[1], page_crawl_results)))
# Out:
#   0%|          | 0/82100 [00:00<?, ?it/s]
# ([('https://store.steampowered.com/app/553850/HELLDIVERS_2/', True),
#   ('https://store.steampowered.com/app/1086940/Baldurs_Gate_3/', True),
#   ('https://store.steampowered.com/app/1172470/Apex_Legends/', True),
#   ('https://store.steampowered.com/app/1158310/Crusader_Kings_III/', True),
#   ('https://store.steampowered.com/app/899770/Last_Epoch/', True),
#   ('https://store.steampowered.com/app/2379780/Balatro/', True),
#   ('https://store.steampowered.com/app/2670630/Supermarket_Simulator/', True),
#   ('https://store.steampowered.com/app/1085660/Destiny_2/', True),
#   ('https://store.steampowered.com/app/230410/Warframe/', True),
#   ('https://store.steampowered.com/app/1938090/Call_of_Duty/', True)],
#  0)

# %%
import re
from typing import TypeVar, Callable
from bs4 import ResultSet, Tag
from tqdm.contrib.concurrent import process_map

T = TypeVar("T")

def extract_one_tag(tag: Tag|None, mapper: Callable[[Tag], T]) -> T|None:
    if tag is None:
        return None
    return mapper(tag)

def extract_all_tags(tags: ResultSet[Tag], mapper: Callable[[Tag], T]) -> list[T]:
    return [mapper(tag) for tag in tags]

# Regex to extract the two numbers based on this template: 84% of the 643 user reviews
review_regex = re.compile(r"(\d+)% of the ([\d,]+) user reviews")

def create_reviews_from_tag(tag: Tag) -> SteamReview|None:
    review_tooltip = str(tag["data-tooltip-html"])
    if review_tooltip == "Need more user reviews to generate a score" or review_tooltip == "No user reviews":
        return None

    match = review_regex.search(review_tooltip)
    if match is None:
        raise ValueError(f"Failed to parse review tooltip {review_tooltip}")

    return SteamReview(
        sentiment=tag.text.strip(),
        number_of_reviewers=int(match.group(2).replace(",", "")),
        positive_percentage=int(match.group(1).replace(",", "")),
    )

def extract_page_information_for_game(game: SteamGame) -> SteamGame:
    page_path = steam_game_pages_path / f"{game.crawled_page_id()}.html"
    assert page_path.exists(), "We should only try to extract page information for games that have been crawled"
    assert game.url_type == "app", "Only crawling app pages is implemented"

    page_content = BeautifulSoup(page_path.read_text(), "html.parser")


    # Get basic properties
    title = page_content.select_one("#appHubAppName")
    type = "dlc" if page_content.select_one(".game_area_dlc_bubble") is not None else "game"
    assert title is not None, f"Each game on Steam should have at least a title, but {game.url} did not have one"
    description = page_content.select_one(".game_area_description")

    release_date = page_content.select_one(".release_date .date")
    tags = page_content.select(".glance_tags.popular_tags a.app_tag")
    developers = page_content.select("#developers_list a")
    publishers = page_content.select(".dev_row + .dev_row .summary.column a")
    genres = page_content.select("#genresAndManufacturer span[data-panel] a")

    price = page_content.select_one(".game_area_purchase_game_wrapper .game_area_purchase_game:not(.dynamic_bundle_description) div[data-price-final]")
    all_reviews = page_content.select_one("#review_histogram_rollup_section .game_review_summary")
    recent_reviews = page_content.select_one("#review_histogram_recent_section .game_review_summary")


    # Images
    images = page_content.select("#highlight_strip .highlight_strip_screenshot img")

    try:
        return SteamGame(
            id=game.id,
            url=game.url,
            raw_name=game.raw_name,
            url_type=game.url_type,
            popularity_rank=game.popularity_rank,
            page_information=SteamPageInformation(
                title=title.text.strip(),
                description=extract_one_tag(description, lambda tag: tag.text.strip()),
                type=type,
                release_date=extract_one_tag(release_date, lambda tag: tag.text.strip()),
                tags=extract_all_tags(tags, lambda tag: tag.text.strip()),
                developers=extract_all_tags(developers, lambda tag: tag.text.strip()),
                publishers=extract_all_tags(publishers, lambda tag: tag.text.strip()),
                genres=extract_all_tags(genres, lambda tag: tag.text.strip()),
                price=extract_one_tag(price, lambda tag: int(str(tag["data-price-final"]))),
                all_reviews=extract_one_tag(all_reviews, create_reviews_from_tag),
                recent_reviews=extract_one_tag(recent_reviews, create_reviews_from_tag),
                images=extract_all_tags(images, lambda tag: str(tag["src"])),
            ),
        )
    except Exception as e:
        logger.error(f"Failed to extract information for game {game.url} due to {e}")
        raise e

excluded_ids = set([
    "1675200", # Steam Deck, redirects to a marketing page
    "1696780", # Steam Deck Docking Station - same idea

    # There seem to be some broken IDs. You can spot them because their URLs end in //:
    "657510",
    "1543120",
    "1929910",
    "2313910",
    "2199040",
    "2011531",
    "2011530",
    "2151650",
    "2027270",
    "955790",
    "1936041",
    "1936040",
    "2288250",
    "1999030",
    "2240030",
    "1897163",
])
games_path = data_path / "games.json"
# games = process_map(
#     extract_page_information_for_game,
#     [game for game in steam_games
#      if game.id not in excluded_ids
#      and game.url_type == "app"
#     ],
#     chunksize=50,
# )
# games_path.write_bytes(msgspec.json.format(msgspec.json.encode(games)))
games: list[SteamGame] = msgspec.json.decode(games_path.read_bytes(), type=list[SteamGame])
games[:10]
# Out:
#   0%|          | 0/81867 [00:00<?, ?it/s]
# [SteamGame(id='553850', url='https://store.steampowered.com/app/553850/HELLDIVERS_2/', raw_name='HELLDIVERS_2', url_type='app', popularity_rank=1, page_information=SteamPageInformation(type='game', title='HELLDIVERS™ 2', description='Digital Deluxe Edition Edition includes:‘DP-53\u202fSavior of the Free’ Armor Set.‘Will of the People’ Cape.‘MP-98 Knight’ Weapon.Super Citizen Status.Stratagem Hero Ship Game.‘Steeled Veterans’ Premium Warbond.', price=3999, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_0c79f56fc7be1bd0102f2ca1c92c8f0900daf4fb.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_33e684e9cb2517af1599f0ca2b57d65ee82c2e51.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_8949ed7dd24a02d5ea13b08fc5c04fab400dc4bd.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_50afbbc4d811c38fe9f64c1fc8d7eb9d9da6d24c.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_cb276fe9f0b09683bdbc496f82b405dbe0ffa1f1.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_d0ac3830833a68d19d4a97c70aef0fba20bf0761.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_3b08a991443164a65f84f1bd9f1363e6c2ec4581.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_8f4af550ecbee08abb616b12cbb3896174dce153.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_3d075daf49e21731cd768ee2ea3adf63857f798c.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_bed14617fc317c2d2b59fdc4d8c4f29b8ddf7ed2.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_e45cb071779848564b3d2dcd7c3d38b7bd81cf9c.116x65.jpg?t=1709666906', 'https://cdn.cloudflare.steamstatic.com/steam/apps/553850/ss_5dde7ea6922800dfece2a3a319cb68e4f6f67949.116x65.jpg?t=1709666906'], genres=['Action'], tags=['Action', 'Online Co-Op', 'Third-Person Shooter', 'Multiplayer', 'Co-op', 'Shooter', 'PvE', 'Third Person', 'Space', 'Sci-fi', 'Capitalism', 'Gore', 'Violent', 'Extraction Shooter', 'Comedy', 'Difficult', 'Great Soundtrack', 'Singleplayer', 'Psychological Horror', 'Open World'], developers=['Arrowhead Game Studios'], publishers=['PlayStation PC LLC'], release_date='8 Feb, 2024', recent_reviews=None, all_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=192549, positive_percentage=82))),
#  SteamGame(id='1086940', url='https://store.steampowered.com/app/1086940/Baldurs_Gate_3/', raw_name='Baldurs_Gate_3', url_type='app', popularity_rank=2, page_information=SteamPageInformation(type='game', title="Baldur's Gate 3", description="About This Game\nGather your party and return to the Forgotten Realms in a tale of fellowship and betrayal, sacrifice and survival, and the lure of absolute power.Mysterious abilities are awakening inside you, drawn from a mind flayer parasite planted in your brain. Resist, and turn darkness against itself. Or embrace corruption, and become ultimate evil.From the creators of Divinity: Original Sin 2 comes a next-generation RPG, set in the world of Dungeons & Dragons.Choose from 12 classes and 11 races from the D&D Player's Handbook and create your own identity, or play as an Origin hero with a hand-crafted background. Or tangle with your inner corruption as the Dark Urge, a fully customisable Origin hero with its own unique mechanics and story. Whoever you choose to be, adventure, loot, battle and romance your way across the Forgotten Realms and beyond. Gather your party. Take the adventure online as a party of up to four. Abducted, infected, lost. You are turning into a monster, but as the corruption inside you grows, so does your power. That power may help you to survive, but there will be a price to pay, and more than any ability, the bonds of trust that you build within your party could be your greatest strength. Caught in a conflict between devils, deities, and sinister otherworldly forces, you will determine the fate of the Forgotten Realms together.Forged with the new Divinity 4.0 engine, Baldur’s Gate 3 gives you unprecedented freedom to explore, experiment, and interact with a thriving world filled with characters, dangers, and deceit. A grand, cinematic narrative brings you closer to your characters than ever before. From shadow-cursed forests, to the magical caverns of the Underdark, to the sprawling city of Baldur’s Gate itself, your actions define the adventure, but your choices define your legacy. You will be remembered.  The Forgotten Realms are a vast, detailed, and diverse world, and there are secrets to be discovered all around you – verticality is a vital part of exploration. Sneak, dip, shove, climb, and jump as you journey from the depths of the Underdark to the glittering rooftops of Baldur’s Gate. Every choice you make drives your story forward, each decision leaving your mark on the world. Define your legacy, nurture relationships and create enemies, and solve problems your way. No two playthroughs will ever be the same.allows you to combine your forces in combat and simultaneously attack enemies, or split your party to each follow your own quests and agendas. Concoct the perfect plan together… or introduce an element of chaos when your friends least expect it. Relationships are complicated. Especially when you’ve got a parasite in your brain. 7 unique Origin heroes offer a hand-crafted experience, each with their own unique traits, agenda, and outlook on the world. Their stories intersect with the overarching narrative, and your choices will determine whether those stories end in redemption, salvation, domination, or one of many other outcomes. Play as an Origin and enjoy their stories, or recruit them to fight alongside you.  based on the D&D 5e ruleset. Team-based initiative, advantage and disadvantage, and roll modifiers join an advanced AI, expanded environmental interactions, and a new fluidity in combat that rewards strategy and foresight. Three difficulty settings allow you to customise the challenge of combat. Enable weighted dice to help sway the battle, or play on Tactician mode for a hardcore experience.   featuring 31 subraces on top of the 11 races (Human, Githyanki, Half-Orc, Dwarf, Elf, Drow, Tiefling, Halfling, Half Elf, Gnome, Dragonborn), with 46 subclasses branching out of the 12 classes. Over 600 spells and actions offer near-limitless freedom o ...
#  SteamGame(id='1172470', url='https://store.steampowered.com/app/1172470/Apex_Legends/', raw_name='Apex_Legends', url_type='app', popularity_rank=3, page_information=SteamPageInformation(type='game', title='Apex Legends™', description="Reviews\n“The champion of Battle Royales.”9/10 – GameSpot“The best Battle Royale game.”5/5 – GamesRadar+“Free, friendly, and consistently fun.  It's the best Battle Royale game available today.”93/100 – PC Gamer", price=None, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_b5051a24edf949582756c313eebf6f61582ce25f.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_ed4087e1f7e85905df637304ac4e511def7943e7.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_a47a8c9b09393bd4cddfeb2891beb4d1eafb2897.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_c75144f4a9c3771806a72ff939752c15456aa557.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_215051168b1b52177d802ab36e40a6f874db404a.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_d83cbff470fc50074354e342554bb0f95873c4cd.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_d2230cd3d1f158423885395003845c6c44168899.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_98f91773af2d5b05d885bc39b13336e7acb23b0b.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_94d9763594de33ec9bdc15ff4cdf3d32cdf59bcb.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_addcfffc4cb07dbde19cd033759054138aa2bc62.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_4f4164594467c9b95d806fe097b0b42c2ffc533b.116x65.jpg?t=1708706824', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1172470/ss_6812fedeafc652ff34b20e0f07ebca1c4aaaa380.116x65.jpg?t=1708706824'], genres=['Action', 'Adventure', 'Free to Play'], tags=['Free to Play', 'Battle Royale', 'Multiplayer', 'FPS', 'Shooter', 'First-Person', 'PvP', 'Action', 'Hero Shooter', 'Team-Based', 'Tactical', 'Sci-fi', 'Survival', 'Loot', 'Character Customization', 'Funny', 'Co-op', 'Lore-Rich', 'Cyberpunk', 'Horror'], developers=['Respawn Entertainment'], publishers=['Electronic Arts'], release_date='4 Nov, 2020', recent_reviews=SteamReview(sentiment='Mixed', number_of_reviewers=14605, positive_percentage=65), all_reviews=SteamReview(sentiment='Mostly Positive', number_of_reviewers=801213, positive_percentage=78))),
#  SteamGame(id='1158310', url='https://store.steampowered.com/app/1158310/Crusader_Kings_III/', raw_name='Crusader_Kings_III', url_type='app', popularity_rank=4, page_information=SteamPageInformation(type='game', title='Crusader Kings III', description='Reviews\n“A new king of historical strategy has been crowned.”10/10 – IGN“Crusader Kings 3 is my Game of the Year so far.”5/5 – VG 24/7“... Crusader Kings 3 is incredible.”94% – PC Gamer', price=2499, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_950a6f6dc67f521877345db6d2c0cebb27ddc528.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_bdb27001b47f80b07024e392f57fdc1944e05a23.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_8935f82df46266a193bd088085978629fb8cf7ec.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_e23d2fb8a8f397025d063260bb458ad6adc6048b.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_8b53c852845e15a7967579b614bc2cf78f6e03df.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_cf57a69ff61043267e4ec9872e1e837e04389a1b.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_790fd253d09664e664bb8e6cbd747f82d3f7c6fa.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_21f4217602effcfbccc4afec373dd0428d2ecd47.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_19794af348e497762f0cd324693ae85c656d5578.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_9e72d22d82b72b15235d8e637d2b1bf8d83e2828.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_fc261abed0befdd73ff2d85c15157ef007a3e987.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_edccc7d63e40b847b67a39777a4fbfb425fd7394.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_191539df1ec9fc14b2700334ec282957e8e6f6ed.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_bd796a730113c2d44b0e025dd2c352cb179711ce.116x65.jpg?t=1709571492', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1158310/ss_ac0ea36ae1b379806728f0ec9220fc10396e62fe.116x65.jpg?t=1709571492'], genres=['RPG', 'Simulation', 'Strategy'], tags=['Strategy', 'Simulation', 'Medieval', 'Grand Strategy', 'RPG', 'Historical', 'Management', 'Character Customization', 'RTS', 'Life Sim', 'Sandbox', 'Choices Matter', 'War', 'Singleplayer', '4X', 'Economy', 'Moddable', 'Political', 'Multiplayer', 'Real-Time with Pause'], developers=['Paradox Development Studio'], publishers=['Paradox Interactive'], release_date='1 Sep, 2020', recent_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=923, positive_percentage=86), all_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=67424, positive_percentage=92))),
#  SteamGame(id='899770', url='https://store.steampowered.com/app/899770/Last_Epoch/', raw_name='Last_Epoch', url_type='app', popularity_rank=5, page_information=SteamPageInformation(type='game', title='Last Epoch', description='Editions Comparison', price=3399, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_3d0b726afdabc5b741065fab2ca45516c92e5189.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_7bb351d2b4344d96123631deb9239448709e11ab.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_14736615a1cbab6f608f9b219cf3eea849d4934d.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_82f015b200420398447bef8a1bbb75cd8951ed5c.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_cd75d3f18ddaf528175e8c948234026b12e60ef2.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_f9e078d5e422403bf14804d0220fa887f20fbfb8.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_e51b2a99932a05cc5e97da15080b358835c66343.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_2e36b4ef4b1682679932004ab95540ae2d4456f5.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_891ba3a7160fd6820f6645811c1130aa38f6d699.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_69a8cd8cd8b4788122a639f23fa9f544890823d8.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_3c139fc4555ec7ff180310848c5f59a2b679598f.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_a4fc70632fb79fb6038649499050fcfcd18ea34b.116x65.jpg?t=1709060046', 'https://cdn.cloudflare.steamstatic.com/steam/apps/899770/ss_8c8166cac21b3b2b6a46e9a801133f73ba8c85fc.116x65.jpg?t=1709060046'], genres=['Action', 'Adventure', 'Indie', 'RPG'], tags=['Action RPG', 'Loot', 'Hack and Slash', 'RPG', 'Isometric', 'Multiplayer', 'Action', 'Adventure', 'Indie', 'Co-op', 'Dungeon Crawler', 'Singleplayer', 'Top-Down', 'Early Access', 'Gore', 'Violent', 'Fantasy', 'Character Customization', 'Magic', 'Time Travel'], developers=['Eleventh Hour Games'], publishers=['Eleventh Hour Games'], release_date='21 Feb, 2024', recent_reviews=SteamReview(sentiment='Mostly Positive', number_of_reviewers=48116, positive_percentage=72), all_reviews=SteamReview(sentiment='Mostly Positive', number_of_reviewers=72257, positive_percentage=76))),
#  SteamGame(id='2379780', url='https://store.steampowered.com/app/2379780/Balatro/', raw_name='Balatro', url_type='app', popularity_rank=6, page_information=SteamPageInformation(type='game', title='Balatro', description="Reviews\n“This is an absolute triumph, the reason Valve should rename their handheld 'the Balatro machine”91 – PC Gamer“Balatro is one of the best deck-building roguelikes I have ever played.”10 – Xbox Era“Balatro is an addictively delicious, menacing creation which devours hours without mercy.”5 Stars – ScreenRant", price=1399, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_d17a3adc6176c7f99e0dc31c49f4764f137e6374.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_4862112e5030f74a5818cd4c31347d699ac5adf3.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_3be65a7dd3be072d567e11883d208861a7e959fa.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_e32ac94d7d1d6be7dd015d78f2b52aeb4cc282ed.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_b8455573ec1fd2c9412f22bd8df05f2d8027a95b.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_075cb45cbfa97d8139fb11f21667d6e35f908640.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_ae055e0e583ac65000920ce33511df73f40814f4.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_204350350761316ad3aa8b0184689f3f93e01f7b.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_ddee13031ad8ba66ac7806a46f6e5519d32e767d.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_d131f3a090667e52ecbf57a0dfcca8851535c627.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_e52b658ebc79c633063e58d77e73ca9750e01039.116x65.jpg?t=1709738226', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2379780/ss_5ab29592c9b5cafe5ce787740afc411eecb9664a.116x65.jpg?t=1709738226'], genres=['Casual', 'Indie', 'Strategy'], tags=['Roguelike Deckbuilder', 'Card Game', 'Deckbuilding', 'Roguelike', 'Card Battler', 'Singleplayer', 'Turn-Based', 'Strategy', 'Choices Matter', 'Replay Value', 'Casual', 'Pixel Graphics', 'Turn-Based Strategy', 'Roguelite', 'Difficult', '2D', 'Simulation', 'Procedural Generation', 'Relaxing', 'Arcade'], developers=['LocalThunk'], publishers=['Playstack'], release_date='20 Feb, 2024', recent_reviews=None, all_reviews=SteamReview(sentiment='Overwhelmingly Positive', number_of_reviewers=13782, positive_percentage=97))),
#  SteamGame(id='2670630', url='https://store.steampowered.com/app/2670630/Supermarket_Simulator/', raw_name='Supermarket_Simulator', url_type='app', popularity_rank=7, page_information=SteamPageInformation(type='game', title='Supermarket Simulator', description='See Other Games https://store.steampowered.com/app/2530950/Rock_Star_Life_Simulator/https://store.steampowered.com/app/2547750/EStartup_2__Business_Tycoon/', price=1299, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_ee99c15d72be4149b24620c945cef9b129fdade7.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_da288dfd94c052144397fb8833392ebf56448d96.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_e429f14874ca193c42d4266408745af466ef13e3.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_fc219472c039df8e41dc13b97e6d678111659b70.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_5f1e8140d1df92bb47d857344b2b0864d985e5da.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_2e4e73a9e638eb0a38de0478536fdc94372b1aa4.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_7f7e4b32a3e754ab9cba572180f1997793696e8a.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_fac423ead6940aa95aafc853c510f468a4837009.116x65.jpg?t=1708875110', 'https://cdn.cloudflare.steamstatic.com/steam/apps/2670630/ss_6728f2c642e025b45415b42d33d400b736bf0368.116x65.jpg?t=1708875110'], genres=['Casual', 'Indie', 'Simulation', 'Early Access'], tags=['Simulation', 'Economy', 'Management', 'Immersive Sim', 'Capitalism', 'Trading', 'Building', 'First-Person', 'Life Sim', 'Sandbox', 'Singleplayer', '3D', 'Casual', 'Driving', 'Resource Management', 'Realistic', 'Indie', 'Inventory Management', 'Early Access', 'Multiplayer'], developers=['Nokta Games'], publishers=['Nokta Games'], release_date='20 Feb, 2024', recent_reviews=None, all_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=6589, positive_percentage=94))),
#  SteamGame(id='1085660', url='https://store.steampowered.com/app/1085660/Destiny_2/', raw_name='Destiny_2', url_type='app', popularity_rank=8, page_information=SteamPageInformation(type='game', title='Destiny 2', description="Season of the Wish Destiny 2: Season of the Wish AwaitsAll hope lies hidden in a land of dreams, a final wish, and a dangerous trade.Dream of DragonsThe path to follow the Witness into the Traveler remains unknown. In the wake of our endeavor with the Hive, our gaze turns to the Dreaming City and Riven, the last of the Ahamkara. All hope lies in a bargain with a wish-dragon known for her clever manipulation.Coil Through Riven's LairIf you can find the last of the Ahamkara eggs, hidden deep beneath the Dreaming City, Riven promises to grant her 15th and final wish. Fight your way through an uncoiling labyrinth, clear her lair of enemies, claim a treasure trove of new rewards, and recover Riven's eggs to save her species.Decipher a New Exotic MissionThe stars will be your guide through the Dreaming City and beyond as you discover secret ties that bind. Earn Wish-Keeper, an Exotic weapon of exquisite power and beauty. Available December 19, 2023.Wish for More WishesThis Season promises wishes upon wishes. Wield a weapon that combines dragon fire and a Rocket Launcher. Score limited-edition cosmetics at the Eververse store inspired by Geralt of Rivia. Unlock more than 100 rewards, including new Seasonal gear, a Ritual Sword, a Competitive PVP Pulse Rifle, Season of the Undying weapons, and more.Find Your Perfect FireteamWant an easier way to team up for Destiny 2’s toughest challenges? Try out the new Fireteam Finder. The beta version, launching November 30, will help Guardians find like-minded gamers for dungeons, with more matchmaking capabilities coming later in the Season. Players can assign tags to themselves and match with a team of their choosing, based on other gamers’ tags.Get the Gift That Keeps on GivingThe Season also includes the annual holiday event, the Dawning, with its own bounties, treats, gifts, festive cosmetics, and yes, snowball fights.", price=5999, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_7fcc82f468fcf8278c7ffa95cebf949bfc6845fc.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_c142f5078ace9f5e2eb2c80aa3bf768e156b4ee9.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_a9642404e586be28f856e8f02d038828f691a5ba.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_01fdd090ed1dd70112ce2c6d6fc208df0a008ac7.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_d230d30da82a7b92c842e7447ee5a8458b866251.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_5065e2bb5de91535dc5e390e27e391a8b9b367ee.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_afc1f202f7ab71adca7d1e503138d89c5689e716.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_324e79ed624f3abd7a2eea2d187d6f616be17102.116x65.jpg?t=1707950251', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1085660/ss_a35aaa73e605c0738a53a74abbcb53768e8f39e1.116x65.jpg?t=1707950251'], genres=['Action', 'Adventure', 'Free to Play'], tags=['Free to Play', 'Open World', 'FPS', 'Looter Shooter', 'MMORPG', 'Co-op', 'Multiplayer', 'PvE', 'PvP', 'Shooter', 'Massively Multiplayer', 'Loot', 'First-Person', 'Sci-fi', 'Action', 'Lore-Rich', 'Adventure', 'Space', 'Competitive', 'Atmospheric'], developers=['Bungie'], publishers=['Bungie'], release_date='1 Oct, 2019', recent_reviews=SteamReview(sentiment='Mostly Positive', number_of_reviewers=3557, positive_percentage=71), all_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=585051, positive_percentage=80))),
#  SteamGame(id='230410', url='https://store.steampowered.com/app/230410/Warframe/', raw_name='Warframe', url_type='app', popularity_rank=9, page_information=SteamPageInformation(type='game', title='Warframe', description='New DLC Available', price=None, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/230410/ss_2e4077f215eccde84171a4b8e0f2bc8a3264c776.116x65.jpg?t=1708445781', 'https://cdn.cloudflare.steamstatic.com/steam/apps/230410/ss_0a541a8bf59e212870ea8d82260ac1b3ae2d0354.116x65.jpg?t=1708445781', 'https://cdn.cloudflare.steamstatic.com/steam/apps/230410/ss_ce00a212a29e9a6c1fc37b16dbd802b2844a901d.116x65.jpg?t=1708445781', 'https://cdn.cloudflare.steamstatic.com/steam/apps/230410/ss_29355e0546599c72002b34b42fe952329df61c2e.116x65.jpg?t=1708445781', 'https://cdn.cloudflare.steamstatic.com/steam/apps/230410/ss_e1d1bfebe225c85ea284ffecfe279c2695ddf3a5.116x65.jpg?t=1708445781', 'https://cdn.cloudflare.steamstatic.com/steam/apps/230410/ss_b06620c448c51d2bc5b71144a184da9ba37b703e.116x65.jpg?t=1708445781'], genres=['Action', 'RPG', 'Free to Play'], tags=['Free to Play', 'Action RPG', 'Looter Shooter', 'Third-Person Shooter', 'Action', 'RPG', 'Third Person', 'Character Customization', 'Massively Multiplayer', 'Online Co-Op', 'Co-op', 'Singleplayer', 'PvE', 'Sci-fi', 'Space', 'Shooter', 'Lore-Rich', 'Hack and Slash', 'Parkour', 'Ninja'], developers=['Digital Extremes'], publishers=['Digital Extremes'], release_date='25 Mar, 2013', recent_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=5422, positive_percentage=88), all_reviews=SteamReview(sentiment='Very Positive', number_of_reviewers=566030, positive_percentage=87))),
#  SteamGame(id='1938090', url='https://store.steampowered.com/app/1938090/Call_of_Duty/', raw_name='Call_of_Duty', url_type='app', popularity_rank=10, page_information=SteamPageInformation(type='game', title='Call of Duty®', description='Call of Duty®: Modern Warfare II Learn more about Call of Duty®: Modern Warfare II here.https://store.steampowered.com/app/1962660/', price=6999, images=['https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_f361412bb8c9266736e9492cff6ffcc45bc603ed.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_e5fa3eae53b2977dcfe97d9556126773c6e76006.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_d73efe087d627eca7419e3869e25dda164b1c1b1.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_540e7e92a3149d545886864b171565622f69f8a8.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_c1ce6b0ee26d1699c758c81adddc036e52b0e997.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_f2eca82ef8096c3e007fea0876e6ccd8f1cbf52f.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_3e5bc42e224c0e731f5f03bb79f2e9062088b679.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_e4a703468d0b837e9d47f60e4b011f89a75625c5.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_8d44444fa57eb4cc808c52b8813c5e9513117835.116x65.jpg?t=1709228756', 'https://cdn.cloudflare.steamstatic.com/steam/apps/1938090/ss_ee9779288267e02fce9b0b2a48d919ea26d87569.116x65.jpg?t=1709228756'], genres=['Action'], tags=['FPS', 'Multiplayer', 'Shooter', 'Action', 'Singleplayer', 'Military', 'First-Person', 'War', 'Modern', 'Tactical', 'Violent', 'Co-op', 'Realistic', 'Story Rich', 'Atmospheric', 'Mature', 'Online Co-Op', 'Gore', 'Third-Person Shooter', 'Third Person'], developers=['Sledgehammer Games', 'Treyarch', 'Infinity Ward', 'Beenox', 'Raven Software', 'High Moon Studios', 'Demonware'], publishers=['Activision'], release_date='27 Oct, 2022', recent_reviews=SteamReview(sentiment='Mixed', number_of_reviewers=7853, positive_percentage=55), all_reviews=SteamReview(sentiment='Mixed', number_of_reviewers=299213, positive_percentage=54)))]

# %%
# Out:
# 242675244
